# %%
import subprocess
import os

# %%
def match_gaia(group):
    ifmt1 = 'csv'
    ifmt2 = 'csv'
    out = f'/home/seba/Documents/DECALS/Galaxies/Galaxies_{group}'
    ofmt = 'csv'
    ra1 = 'ra'
    dec1 = 'dec'
    ra2 = '_RAJ2000'
    dec2 = '_DEJ2000'
    error = 5
    in1 = f'/home/seba/Documents/DECALS/Catalogs_raw/{group}'
    in2 = '/home/seba/Documents/CG/Hernandez-Fernandez/Galaxy_catalogue.csv'
    subprocess.run(f'stilts tskymatch2 ifmt1={ifmt1} ifmt2={ifmt2} out={out} ofmt={ofmt} ra1={ra1} dec1={dec1} ra2={ra2} dec2={dec2} error={error} in1={in1} in2={in2}', shell=True)

# %%
archivos = os.listdir('/home/seba/Documents/DECALS/Catalogs_raw/')

# %%
for group in archivos:
    match_gaia(group)
# Out:
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 67.44467 .. 67.64505, 6.841227 .. 7.039214
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 67.443275 .. 67.64645, 6.839838 .. 7.0406027
# Counting rows in match region for table 1.....................................
# 1870 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 1 bins
# (average bin occupancy 4.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 9.324675 .. 9.52652, -9.15625 .. -8.957071
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 9.323268 .. 9.527926, -9.1576395 .. -8.955682
# Counting rows in match region for table 1.....................................
# 4009 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 353.6137 .. 353.91116, -48.074535 .. -47.8753
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 353.61163 .. 353.91324, -48.075924 .. -47.873913
# Counting rows in match region for table 1.....................................
# 5025 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 169.40048 .. 169.63118, 30.435429 .. 30.634748
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 169.39886 .. 169.63278, 30.43404 .. 30.636137
# Counting rows in match region for table 1.....................................
# 2922 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 33.546555 .. 33.812553, -41.741695 .. -41.54301
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 33.544693 .. 33.814415, -41.743084 .. -41.541622
# Counting rows in match region for table 1.....................................
# 6043 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 16.067722 .. 16.26734, -2.2328744 .. -2.034279
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 16.066332 .. 16.268728, -2.2342632 .. -2.0328903
# Counting rows in match region for table 1.....................................
# 4519 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 174.6291 .. 174.82823, 3.4868832 .. 3.6856785
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 174.62772 .. 174.82962, 3.4854941 .. 3.6870673
# Counting rows in match region for table 1.....................................
# 2840 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 47.00346 .. 47.29738, -47.374306 .. -47.17465
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 47.001408 .. 47.299427, -47.375694 .. -47.17326
# Counting rows in match region for table 1.....................................
# 5733 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 49.967384 .. 50.227814, -40.29275 .. -40.09345
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 49.96556 .. 50.229637, -40.29414 .. -40.09206
# Counting rows in match region for table 1.....................................
# 5131 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 76.01965 .. 76.23024, -18.784761 .. -18.58655
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 76.01818 .. 76.23171, -18.78615 .. -18.585161
# Counting rows in match region for table 1.....................................
# 5188 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.2)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 29.547935 .. 29.787718, -33.857155 .. -33.65771
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 29.546263 .. 29.789389, -33.858543 .. -33.656322
# Counting rows in match region for table 1.....................................
# 5825 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 210.35403 .. 210.55252, -3.280981 .. -3.0825436
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 210.35265 .. 210.55391, -3.2823699 .. -3.0811546
# Counting rows in match region for table 1.....................................
# 3042 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.25)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 26.480064 .. 26.680016, -7.431363 .. -7.2321324
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 26.478664 .. 26.681416, -7.432752 .. -7.230744
# Counting rows in match region for table 1.....................................
# 4414 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.4)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 202.91783 .. 203.17389, -38.986496 .. -38.78735
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 202.91605 .. 203.17567, -38.987885 .. -38.78596
# Counting rows in match region for table 1.....................................
# 6120 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 4.4853725 .. 4.7542105, -42.2275 .. -42.027775
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 4.483497 .. 4.756086, -42.22889 .. -42.026386
# Counting rows in match region for table 1.....................................
# 8913 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 3 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 70.43137 .. 70.64844, -23.34435 .. -23.145613
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 70.42986 .. 70.64995, -23.345741 .. -23.144224
# Counting rows in match region for table 1.....................................
# 4784 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 245.71358 .. 245.921, 15.7047205 .. 15.903848
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 245.71213 .. 245.92244, 15.703332 .. 15.905236
# Counting rows in match region for table 1.....................................
# 3464 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 137.05339 .. 137.2845, 30.787525 .. 30.986906
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 137.05177 .. 137.28612, 30.786135 .. 30.988295
# Counting rows in match region for table 1.....................................
# 2804 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 211.0878 .. 211.30647, 24.084085 .. 24.282705
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 211.08627 .. 211.308, 24.082697 .. 24.284094
# Counting rows in match region for table 1.....................................
# 2887 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 23.145544 .. 23.709042, -69.42127 .. -69.22147
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 23.141592 .. 23.712994, -69.42266 .. -69.220085
# Counting rows in match region for table 1.....................................
# 7685 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 66.183716 .. 66.647095, -64.56034 .. -64.361
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 66.18048 .. 66.65033, -64.56173 .. -64.35961
# Counting rows in match region for table 1.....................................
# 9186 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.25)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 335.39606 .. 335.81168, -61.38359 .. -61.184227
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 335.39316 .. 335.81458, -61.38498 .. -61.18284
# Counting rows in match region for table 1.....................................
# 5707 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 351.76877 .. 352.06143, -47.147007 .. -46.948246
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 351.76672 .. 352.06348, -47.1484 .. -46.946854
# Counting rows in match region for table 1.....................................
# 5197 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 238.55298 .. 238.78328, 30.02541 .. 30.22313
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 238.55138 .. 238.78488, 30.024021 .. 30.224518
# Counting rows in match region for table 1.....................................
# 2282 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 358.61337 .. 358.9235, -50.16216 .. -49.963223
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 358.6112 .. 358.92566, -50.163548 .. -49.961834
# Counting rows in match region for table 1.....................................
# 4782 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 24.436125 .. 25.1804, -74.52284 .. -74.323006
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 24.43092 .. 25.185606, -74.52423 .. -74.32162
# Counting rows in match region for table 1.....................................
# 13831 rows in match region
# Counting rows in match region for table 2.....................................
# 6 rows in match region
# Binning rows for table 2......................................................
# 1187/1193 rows excluded (out of match region)
# 8 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.6)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 73.239784 .. 73.48577, -36.353195 .. -36.153526
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 73.23806 .. 73.487495, -36.354584 .. -36.152138
# Counting rows in match region for table 1.....................................
# 5863 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 204.77596 .. 204.97491, 4.4111533 .. 4.610389
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 204.77457 .. 204.9763, 4.4097643 .. 4.611778
# Counting rows in match region for table 1.....................................
# 3261 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 3 bins
# (average bin occupancy 2.3333333)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 213.11855 .. 213.33575, 23.231726 .. 23.43137
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 213.11703 .. 213.33727, 23.230337 .. 23.432758
# Counting rows in match region for table 1.....................................
# 2652 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 331.94763 .. 332.31543, -57.38876 .. -57.189133
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 331.94507 .. 332.31802, -57.39015 .. -57.187744
# Counting rows in match region for table 1.....................................
# 4769 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 161.69905 .. 161.89752, -2.4355502 .. -2.2379036
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 161.69766 .. 161.89891, -2.436939 .. -2.2365148
# Counting rows in match region for table 1.....................................
# 3233 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 12.753586 .. 12.970096, -23.315134 .. -23.11587
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 12.752073 .. 12.971608, -23.316523 .. -23.114481
# Counting rows in match region for table 1.....................................
# 5837 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 51.49913 .. 51.771286, -42.929665 .. -42.730385
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 51.49723 .. 51.773182, -42.931053 .. -42.728996
# Counting rows in match region for table 1.....................................
# 5074 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 3 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 6.099636 .. 6.505453, -60.729813 .. -60.529972
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 6.096795 .. 6.508294, -60.731205 .. -60.528584
# Counting rows in match region for table 1.....................................
# 5481 rows in match region
# Counting rows in match region for table 2.....................................
# 6 rows in match region
# Binning rows for table 2......................................................
# 1187/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.4)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 199.78535 .. 199.99045, 13.992033 .. 14.190386
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 199.78392 .. 199.99187, 13.9906435 .. 14.191774
# Counting rows in match region for table 1.....................................
# 2857 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 210.87003 .. 211.09193, 26.273424 .. 26.472254
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 210.86848 .. 211.09349, 26.272036 .. 26.473642
# Counting rows in match region for table 1.....................................
# 2600 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 340.67728 .. 340.91882, -34.73065 .. -34.532814
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 340.67557 .. 340.9205, -34.73204 .. -34.53142
# Counting rows in match region for table 1.....................................
# 2130 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.25)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 230.0587 .. 230.28899, 30.368086 .. 30.565746
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 230.05708 .. 230.2906, 30.366697 .. 30.567135
# Counting rows in match region for table 1.....................................
# 2589 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 141.90645 .. 142.12843, 26.406448 .. 26.605545
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 141.90489 .. 142.12997, 26.40506 .. 26.606936
# Counting rows in match region for table 1.....................................
# 2300 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 72.044525 .. 72.72841, -73.16849 .. -72.96929
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 72.03973 .. 72.73321, -73.169876 .. -72.9679
# Counting rows in match region for table 1.....................................
# 3596 rows in match region
# Counting rows in match region for table 2.....................................
# 6 rows in match region
# Binning rows for table 2......................................................
# 1187/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.75)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 230.39606 .. 230.59525, 3.4610097 .. 3.6595383
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 230.39467 .. 230.59663, 3.459621 .. 3.6609273
# Counting rows in match region for table 1.....................................
# 3604 rows in match region
# Counting rows in match region for table 2.....................................
# 6 rows in match region
# Binning rows for table 2......................................................
# 1187/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 3 bins
# (average bin occupancy 2.3333333)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 4.0941315 .. 4.410645, -51.16042 .. -50.961384
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 4.091917 .. 4.41286, -51.16181 .. -50.959995
# Counting rows in match region for table 1.....................................
# 8037 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 9 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.8)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 66.588806 .. 66.89351, -49.219036 .. -49.019447
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 66.58668 .. 66.89564, -49.220425 .. -49.01806
# Counting rows in match region for table 1.....................................
# 5397 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 8 row refs for 1193 rows in 4 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 174.15536 .. 174.35927, 12.357564 .. 12.5551405
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 174.15395 .. 174.3607, 12.356174 .. 12.556529
# Counting rows in match region for table 1.....................................
# 2129 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 2 bins
# (average bin occupancy 3.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 202.38895 .. 202.59053, 9.322484 .. 9.521504
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 202.38754 .. 202.59193, 9.321095 .. 9.522894
# Counting rows in match region for table 1.....................................
# 2644 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 129.61943 .. 129.81874, 1.3004535 .. 1.4989017
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 129.61804 .. 129.82013, 1.2990648 .. 1.5002906
# Counting rows in match region for table 1.....................................
# 4356 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# ...
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 21.060246 .. 21.261211, -8.286329 .. -8.087932
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 21.058842 .. 21.262615, -8.287718 .. -8.086543
# Counting rows in match region for table 1.....................................
# 2955 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 4.163475 .. 4.72364, -69.248566 .. -69.0492
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 4.159555 .. 4.7275605, -69.249954 .. -69.04781
# Counting rows in match region for table 1.....................................
# 6291 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 4 bins
# (average bin occupancy 1.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 201.9018 .. 202.13562, 31.8398 .. 32.039413
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 201.90016 .. 202.13725, 31.83841 .. 32.040802
# Counting rows in match region for table 1.....................................
# 2819 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 7 row refs for 1193 rows in 5 bins
# (average bin occupancy 1.4)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 330.51547 .. 330.73193, -22.993963 .. -22.794537
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 330.51395 .. 330.73343, -22.995354 .. -22.793148
# Counting rows in match region for table 1.....................................
# 6486 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 314.37558 .. 314.59464, -25.064299 .. -24.864801
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 314.37402 .. 314.59616, -25.065687 .. -24.863413
# Counting rows in match region for table 1.....................................
# 2800 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 211.74911 .. 211.95348, 12.616633 .. 12.815476
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 211.7477 .. 211.9549, 12.615244 .. 12.816865
# Counting rows in match region for table 1.....................................
# 2998 rows in match region
# Counting rows in match region for table 2.....................................
# 5 rows in match region
# Binning rows for table 2......................................................
# 1188/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.5)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 15.467564 .. 15.676094, -17.301271 .. -17.101421
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 15.466109 .. 15.677549, -17.302662 .. -17.100033
# Counting rows in match region for table 1.....................................
# 5170 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 14.282743 .. 14.528174, -35.857014 .. -35.658165
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 14.28103 .. 14.529888, -35.858402 .. -35.656776
# Counting rows in match region for table 1.....................................
# 6602 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 64.07854 .. 64.2765, 0.17327656 .. 0.37155962
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 64.07715 .. 64.277885, 0.17188767 .. 0.3729485
# Counting rows in match region for table 1.....................................
# 2671 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 222.60193 .. 222.81618, 21.649038 .. 21.847618
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 222.60043 .. 222.81767, 21.64765 .. 21.849009
# Counting rows in match region for table 1.....................................
# 3103 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 355.62164 .. 355.82568, -13.157963 .. -12.958841
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 355.6202 .. 355.82712, -13.159352 .. -12.957452
# Counting rows in match region for table 1.....................................
# 3069 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 2 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 26.785212 .. 27.016302, -30.357664 .. -30.158306
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 26.783602 .. 27.017912, -30.359055 .. -30.156918
# Counting rows in match region for table 1.....................................
# 4828 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 178.95978 .. 179.1802, 25.274158 .. 25.473034
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 178.95825 .. 179.18175, 25.27277 .. 25.474422
# Counting rows in match region for table 1.....................................
# 4454 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 5 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.6666666)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 3.4299192 .. 3.6451185, -22.662243 .. -22.464237
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 3.428414 .. 3.6466236, -22.663631 .. -22.462849
# Counting rows in match region for table 1.....................................
# 2466 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 6 row refs for 1193 rows in 3 bins
# (average bin occupancy 2.0)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
# Params: Max Error(Number)/arcsec=5.0
# Tuning: HEALPix k(Integer)=11
# Attempt to locate restricted common region
# Assessing range of coordinates from table 1...................................
# Limits are: 26.946047 .. 27.152636, -15.220652 .. -15.021057
# Assessing range of coordinates from table 2...................................
# Limits are: 0.0790833 .. 359.875, -74.89922 .. 80.52836
# Potential match region: 26.944609 .. 27.154076, -15.22204 .. -15.019669
# Counting rows in match region for table 1.....................................
# 4790 rows in match region
# Counting rows in match region for table 2.....................................
# 4 rows in match region
# Binning rows for table 2......................................................
# 1189/1193 rows excluded (out of match region)
# 4 row refs for 1193 rows in 3 bins
# (average bin occupancy 1.3333334)
# Scanning rows for table 1.....................................................
# Eliminating multiple row references...........................................
# Elapsed time for match: 0 seconds
